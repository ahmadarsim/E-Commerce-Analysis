# %% [raw]
# Q1: Display Top 10 Rows of the Dataset?
# Q2: Check the Last 10 Rows of the Dataset?
# Q3: Check Datatype of Each Columns?
# Q4: Check Null Values in Dataset?
# Q5: How Many Rows and Columns are There in Our Dataset?
# Q6: Highest and Lowest Purchase Prices?
# Q7: Average Purchase Prices?
# Q8: How Many People Have French 'fr' as Their Language?
# Q9: Job Title Contains Engineer?
# Q10: Find the Email of Person with The Fellowing IP Address?
#  132:207:160:22
# Q10: How Many People Have Mastercard as Their Credit Card Provider and Made a Purchase Above 50?
# Q11: Find Email of The Person with The Fellowing Credit card number?
#  4664825258997302
# 12: how many people purchase during the AM and how many people purchase during PM?
# 13: how many peple have a credit card that expires in 2020?
# 14: Top 5 Most Popular Email providers (gmail.com, yahoo.com etc)

# %%
Download Data set from this link
https://www.kaggle.com/datasets/utkarsharya/ecommerce-purchases?select=Ecommerce+Purchases

# %%
# conver CSV into Json

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/User/Desktop/NEVTTC/EDA/e-commerce/Ecommerce_Purchases.csv")

# %% [markdown]
# ## Q1: Display Top 10 Rows of the Dataset?

# %%
data.head(11)
# Out:
#                                               Address    Lot AM or PM  \
# 0   16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1   9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                    Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3               7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4   23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5   7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6      93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7   260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8             2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9     3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10      650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
#
#                                          Browser Info  \
# 0   Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# ...

# %% [markdown]
# ## Q2: Check the Last 10 Rows of the Dataset?

# %%
data.tail(11)
# Out:
#                                                 Address    Lot AM or PM  \
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# ## Q3: Check Datatype of Each Columns?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase_Price      float64
# dtype: object

# %% [markdown]
# ## Q4: How Many Rows and Columns are There in Our Dataset?

# %%
data.shape
# Out:
# (10000, 14)

# %% [markdown]
# ## Q5: Check Null Values in Dataset?
# OR:
# ## Preprocessing

# %%
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Q6: Highest and Lowest Purchase Prices?

# %%
data.head(1)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
#
#                                         Browser Info          Company  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  Martinez-Herman
#
#         Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 0  6011929061123406       02/20               900  JCB 16 digit
#
#                Email                                     Job       IP Address  \
# 0  pdunlap@yahoo.com  Scientist, product/process development  149.146.147.205
#
#   Language  Purchase Price
# 0       el           98.14

# %%
data.rename(columns={'Purchase Price': 'Purchase_Price'}, inplace = True)

# %%
data.head(1)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
#
#                                         Browser Info          Company  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  Martinez-Herman
#
#         Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 0  6011929061123406       02/20               900  JCB 16 digit
#
#                Email                                     Job       IP Address  \
# 0  pdunlap@yahoo.com  Scientist, product/process development  149.146.147.205
#
#   Language  Purchase_Price
# 0       el           98.14

# %%
data['Purchase_Price'].max()
# Out:
# 99.99

# %%
data[data['Purchase_Price']==99.99]
# Out:
#                                         Address    Lot AM or PM  \
# 2092  63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
# 7807      PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
#
#                                            Browser Info  \
# 2092  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7807  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
#
#                         Company     Credit Card CC Exp Date  CC Security Code  \
# 2092                Pitts Group   4292741269160       06/18               824
# 7807  Porter, Johnson and Pratt  30109394842259       11/25               918
#
#         CC Provider                     Email                     Job  \
# 2092        Maestro  heatherwoodard@lloyd.com  Surveyor, hydrographic
# 7807  VISA 16 digit         kelli72@gmail.com     Surveyor, insurance
#
#            IP Address Language  Purchase_Price
# 2092  172.197.216.229       el           99.99
# 7807     89.51.92.242       de           99.99

# %%
data['Purchase_Price'].min()
# Out:
# 0.0

# %%
data[data['Purchase_Price']==0]
# Out:
#                                                 Address    Lot AM or PM  \
# 2876  332 Jones Parkways\nEast Katherineville, GA 64230  39 GT       AM
# 5487     465 Mallory Ways\nNorth Rebecca, RI 82734-1160  93 OH       PM
#
#                                            Browser Info  \
# 2876  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_9...
# 5487  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 2876  Lyons, Diaz and Clark  4204500444841766       01/18                38
# 5487         Flynn and Sons    30469912089738       09/23               236
#
#         CC Provider                 Email                   Job  \
# 2876  VISA 16 digit  jennifer11@baker.com  Biomedical scientist
# 5487       Discover   mjohnson@austin.org         Stage manager
#
#           IP Address Language  Purchase_Price
# 2876  223.47.177.174       it             0.0
# 5487     43.99.56.59       zh             0.0

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data['Purchase_Price'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Purchase_Price'>

# %% [markdown]
# ## Q7: Average Purchase Prices?

# %%
data['Purchase_Price'].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# ## Q8: How Many People Have French 'fr' as Their Language?

# %%
data['Language'].nunique()
# Out:
# 9

# %%
data['Language'].unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %%
data[data['Language'] == 'fr']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9951                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %%
len(data[data['Language'] == 'fr'])
# Out:
# 1097

# %%
data[data['Language'] == 'fr'].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase_Price      1097
# dtype: int64

# %% [markdown]
# ## Q9: Job Title Contains Engineer?

# %%
data['Job'].nunique()
# Out:
# 623

# %%
data['Job'].unique()
# Out:
# array(['Scientist, product/process development', 'Drilling engineer',
#        'Customer service manager', 'Fine artist', 'Fish farm manager',
#        'Dancer', 'Event organiser', 'Financial manager',
#        'Forensic scientist', 'Development worker, community',
#        'Diagnostic radiographer', 'Surveyor, quantity',
#        'Accountant, chartered public finance', 'Acupuncturist',
#        'Retail manager', 'Therapist, art', 'Designer, jewellery',
#        'Photographer', 'Designer, interior/spatial',
#        'Public relations officer', 'Presenter, broadcasting',
#        'Field seismologist', 'Musician',
#        'Training and development officer', "Barrister's clerk",
#        'Careers adviser', 'Scientist, research (life sciences)',
#        'Recycling officer', 'Fisheries officer', 'Sales executive',
#        'Civil Service fast streamer', 'Theatre stage manager',
#        'Therapist, music', 'Lecturer, further education',
# ...

# %%
data[data['Job'].str.contains('Engineer',case= False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
len(data[data['Job'].str.contains('Engineer',case= False)]
)
# Out:
# 984

# %%
data[data['Job'].str.contains('Engineer',case= False)].count()
# Out:
# Address             984
# Lot                 984
# AM or PM            984
# Browser Info        984
# Company             984
# Credit Card         984
# CC Exp Date         984
# CC Security Code    984
# CC Provider         984
# Email               984
# Job                 984
# IP Address          984
# Language            984
# Purchase_Price      984
# dtype: int64

# %% [markdown]
# ## Q10: Find the Email of Person with The Fellowing IP Address?
# 132:207:160:22

# %%
data.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
data['IP Address'].nunique()
# Out:
# 10000

# %%
data['IP Address'].unique()
# Out:
# array(['149.146.147.205', '15.160.41.51', '132.207.160.22', ...,
#        '156.210.0.254', '55.78.26.143', '176.119.198.199'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase_Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
 data[data['IP Address'] == '132.207.160.22' ]['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# ## Q10: How Many People Have Mastercard as Their Credit Card Provider and Made a Purchase Above 50?

# %%
data['CC Provider'].nunique()
# Out:
# 10

# %%
data['CC Provider'].unique()
# Out:
# array(['JCB 16 digit', 'Mastercard', 'Discover',
#        'Diners Club / Carte Blanche', 'VISA 16 digit', 'VISA 13 digit',
#        'American Express', 'Voyager', 'JCB 15 digit', 'Maestro'],
#       dtype=object)

# %%
data[(data['Purchase_Price'] > 50)  & (data['CC Provider']=='Mastercard') ]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(data[(data['Purchase_Price'] > 50)  & (data['CC Provider']=='Mastercard') ] )
# Out:
# 405

# %%
data[(data['Purchase_Price'] > 50)  & (data['CC Provider']=='Mastercard') ].count()
# Out:
# Address             405
# Lot                 405
# AM or PM            405
# Browser Info        405
# Company             405
# Credit Card         405
# CC Exp Date         405
# CC Security Code    405
# CC Provider         405
# Email               405
# Job                 405
# IP Address          405
# Language            405
# Purchase_Price      405
# dtype: int64

# %% [markdown]
# ## Q11: Find Email of The Person with The Fellowing Credit card number?
#  4664825258997302

# %%
data[data['Credit Card']==4664825258997302]['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %% [markdown]
# ## 12: how many people purchase during the AM and how many people purchase during PM?

# %%
data['AM or PM'].nunique()
# Out:
# 2

# %%
data['AM or PM'].unique()
# Out:
# array(['PM', 'AM'], dtype=object)

# %%
data[data['AM or PM']=='AM']
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# ...                                                 ...    ...      ...
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data[data['AM or PM']=='AM'].count()
# Out:
# Address             4932
# Lot                 4932
# AM or PM            4932
# Browser Info        4932
# Company             4932
# Credit Card         4932
# CC Exp Date         4932
# CC Security Code    4932
# CC Provider         4932
# Email               4932
# Job                 4932
# IP Address          4932
# Language            4932
# Purchase_Price      4932
# dtype: int64

# %%
len(data[data['AM or PM']=='AM'])
# Out:
# 4932

# %%
data[data['AM or PM']=='PM']
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# ...                                                 ...    ...      ...
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
#
#                                            Browser Info  \
# ...

# %%
data[data['AM or PM']=='PM'].count()
# Out:
# Address             5068
# Lot                 5068
# AM or PM            5068
# Browser Info        5068
# Company             5068
# Credit Card         5068
# CC Exp Date         5068
# CC Security Code    5068
# CC Provider         5068
# Email               5068
# Job                 5068
# IP Address          5068
# Language            5068
# Purchase_Price      5068
# dtype: int64

# %%
len(data[data['AM or PM']=='PM'])
# Out:
# 5068

# %%
sns.countplot(x='AM or PM', data=data).set(title="Time of Purchasing")
# Out:
# [Text(0.5, 1.0, 'Time of Purchase')]

# %% [markdown]
# ## 13: how many peple have a credit card that expires in 2020?

# %%
data[data['CC Exp Date']== '02/20']
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 205   43656 Wiggins Ranch Suite 839\nSouth Susan, OK...  89 nV       PM
# 217   7090 Regina Mount Suite 704\nPatrickshire, NJ ...  54 EG       PM
# 649   34470 Ward Mountain Apt. 660\nWendymouth, NY 6...  04 OT       PM
# ...                                                 ...    ...      ...
# 9158  21034 Valdez Meadow Suite 830\nKristenfort, NM...  00 NX       PM
# 9281  039 Ramirez Expressway Suite 438\nConwaytown, ...  06 Of       PM
# 9308              052 Alison View\nJennahaven, ID 86996  40 uz       AM
# 9463       3215 Hurley Green\nPort Shane, WV 99880-9873  91 Ve       PM
# 9710       4721 Garcia Fort\nHowellmouth, PR 81541-3067  50 oG       AM
#
#                                            Browser Info  \
# ...

# %%
data[data['CC Exp Date']== '02/20'].count()
# Out:
# Address             75
# Lot                 75
# AM or PM            75
# Browser Info        75
# Company             75
# Credit Card         75
# CC Exp Date         75
# CC Security Code    75
# CC Provider         75
# Email               75
# Job                 75
# IP Address          75
# Language            75
# Purchase_Price      75
# dtype: int64

# %%
len(data[data['CC Exp Date']== '02/20'])
# Out:
# 75

# %% [markdown]
# ## 14 :Top 5 Most Popular Email providers (gmail.com, yahoo.com etc)

# %%
list=[]
for email in data['Email']:
    
    list.append(email.split('@')[1])

# %%
data['Popular Email Provider'] = list

# %%
data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
data['Popular Email Provider'].nunique()
# Out:
# 3416

# %%
data['Popular Email Provider'].unique()
# Out:
# array(['yahoo.com', 'reed.com', 'morales-harrison.com', ...,
#        'sherman.biz', 'wise-liu.com', 'wade-garner.com'], dtype=object)

# %%
data['Popular Email Provider'].value_counts()
# Out:
# hotmail.com          1638
# yahoo.com            1616
# gmail.com            1605
# smith.com              42
# williams.com           37
#                      ...
# smith-hall.com          1
# diaz-davis.com          1
# haynes.com              1
# lloyd-edwards.com       1
# walters.net             1
# Name: Popular Email Provider, Length: 3416, dtype: int64

# %%
data['Popular Email Provider'].value_counts().head(6).reset_index()
# Out:
#           index  Popular Email Provider
# 0   hotmail.com                    1638
# 1     yahoo.com                    1616
# 2     gmail.com                    1605
# 3     smith.com                      42
# 4  williams.com                      37
# 5     brown.com                      29

# %%
data['Email'].apply(lambda x:x.split('@')[1]).value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
